# %% [markdown]
# <a href="https://colab.research.google.com/github/ugwusimeon2/Python-class/blob/main/pandas_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_table('http://bit.ly/chiporders')
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df.shape
# Out:
# (4622, 5)

# %%
df.describe()
# Out:
#           order_id     quantity
# count  4622.000000  4622.000000
# mean    927.254868     1.075725
# std     528.890796     0.410186
# min       1.000000     1.000000
# 25%     477.250000     1.000000
# 50%     926.000000     1.000000
# 75%    1393.000000     1.000000
# max    1834.000000    15.000000

# %%
df['item_price']=df['item_price'].str.replace('$','').astype(float)

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
df.describe()
# Out:
#           order_id     quantity   item_price
# count  4622.000000  4622.000000  4622.000000
# mean    927.254868     1.075725     7.464336
# std     528.890796     0.410186     4.245557
# min       1.000000     1.000000     1.090000
# 25%     477.250000     1.000000     3.390000
# 50%     926.000000     1.000000     8.750000
# 75%    1393.000000     1.000000     9.250000
# max    1834.000000    15.000000    44.250000

# %%
df.isnull().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
df.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# ...

# %%
df.tail(10)
# Out:
#       order_id  quantity            item_name  \
# 4612      1831         1        Carnitas Bowl
# 4613      1831         1                Chips
# 4614      1831         1        Bottled Water
# 4615      1832         1   Chicken Soft Tacos
# 4616      1832         1  Chips and Guacamole
# 4617      1833         1        Steak Burrito
# 4618      1833         1        Steak Burrito
# 4619      1834         1   Chicken Salad Bowl
# 4620      1834         1   Chicken Salad Bowl
# 4621      1834         1   Chicken Salad Bowl
#
#                                      choice_description  item_price
# 4612  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...        9.25
# 4613                                                NaN        2.15
# 4614                                                NaN        1.50
# 4615   [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]        8.75
# 4616                                                NaN        4.45
# ...

# %%
df.choice_description
# Out:
# 0                                                     NaN
# 1                                            [Clementine]
# 2                                                 [Apple]
# 3                                                     NaN
# 4       [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
#                               ...
# 4617    [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...
# 4618    [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...
# 4619    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...
# 4620    [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...
# 4621    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...
# Name: choice_description, Length: 4622, dtype: object

# %%
df.dtypes
# Out:
# order_id                int64
# quantity                int64
# item_name              object
# choice_description     object
# item_price            float64
# dtype: object

# %%
df = pd.read_csv('http://bit.ly/imdbratings')
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
import pandas as pd

# %%
df.describe()
# Out:
#        star_rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %%
df.isnull().sum()
# Out:
# star_rating       0
# title             0
# content_rating    3
# genre             0
# duration          0
# actors_list       0
# dtype: int64

# %%
import ast
from collections import Counter

# Convert the string of actors to a Python list (if necessary)
df['actors_list'] = df['actors_list'].apply(ast.literal_eval)

# Flatten all actor lists into one long list
all_actors = [actor for sublist in df['actors_list'] for actor in sublist]

# Count how many times each actor appears
actor_counts = Counter(all_actors)

# Find the actor(s) who appeared the most
max_count = max(actor_counts.values())  # highest appearance count
most_actors = [actor for actor, count in actor_counts.items() if count == max_count]

print("Actors who appeared the most (", max_count, "time(s) ):")
print(most_actors)
# Out:
# Actors who appeared the most ( 18 time(s) ):
# ['Robert De Niro']

# %%
# See the first few rows
print(df.head())

# See info about columns, data types, and missing values
print(df.info())

# Quick statistics (only for numeric columns)
print(df.describe())
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                        actors_list
# 0        [Tim Robbins, Morgan Freeman, Bob Gunton]
# 1           [Marlon Brando, Al Pacino, James Caan]
# 2       [Al Pacino, Robert De Niro, Robert Duvall]
# 3    [Christian Bale, Heath Ledger, Aaron Eckhart]
# 4  [John Travolta, Uma Thurman, Samuel L. Jackson]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979 entries, 0 to 978
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
# ...

# %%
# Check how many missing values each column has
print(df.isnull().sum())

# fill missing values with something
df.loc[:, 'genre'] = df['genre'].fillna('Unknown')
# Out:
# star_rating       0
# title             0
# content_rating    0
# genre             0
# duration          0
# actors_list       0
# dtype: int64

# %%
# Check for duplicate rows
print(df.duplicated().sum())

# Remove duplicates
df = df.drop_duplicates()
# Out:
# 0

# %%
df.loc[:, 'actors_list'] = df['actors_list'].astype(str)

print(df.duplicated().sum())  # Now this will work
df = df.drop_duplicates()
# Out:
# 0

# %%
df['genre'] = df['genre'].str.strip().str.lower()
df['content_rating'] = df['content_rating'].str.strip().str.lower()
df['title'] = df['title'].str.strip()

# %%
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                r      crime       142
# 1                r      crime       175
# 2                r      crime       200
# ...

# %%
# Example: replace inconsistent genre names
df['genre'] = df['genre'].replace({
    'sci-fi': 'science fiction',
    'rom-com': 'romance',
    'thriller/suspense': 'thriller'
})

# %%
# Check for outliers in 'duration'
print(df['duration'].describe())

# Remove unrealistic durations
df = df[df['duration'] < 500]
# Out:
# count    976.000000
# mean     120.945697
# std       26.228192
# min       64.000000
# 25%      102.000000
# 50%      117.000000
# 75%      134.000000
# max      242.000000
# Name: duration, dtype: float64

# %%
df = df.rename(columns={
    'star_rating': 'rating',
    'content_rating': 'age_rating'
})

# %%
print(df.info())
print(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 976 entries, 0 to 978
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   rating       976 non-null    float64
#  1   title        976 non-null    object
#  2   age_rating   976 non-null    object
#  3   genre        976 non-null    object
#  4   duration     976 non-null    int64
#  5   actors_list  976 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 53.4+ KB
# None
#    rating                     title age_rating   genre  duration  \
# 0     9.3  The Shawshank Redemption          r   crime       142
# 1     9.2             The Godfather          r   crime       175
# 2     9.1    The Godfather: Part II          r   crime       200
# 3     9.0           The Dark Knight      pg-13  action       152
# 4     8.9              Pulp Fiction          r   crime       154
#
#                                          actors_list
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set a clean, professional style
sns.set(style="whitegrid")

# %%
sns.histplot(df['rating'], bins=10, kde=True)
plt.title("Distribution of Movie Ratings")
plt.xlabel("Rating")
plt.ylabel("Frequency")
plt.show()

# %%
df.columns = df.columns.str.strip().str.lower()
print(df.columns)
# Out:
# Index(['rating', 'title', 'age_rating', 'genre', 'duration', 'actors_list'], dtype='object')

# %%
plt.figure(figsize=(10, 6))
sns.countplot(y='genre', data=df, order=df['genre'].value_counts().index)
plt.title("Number of Movies by Genre")
plt.xlabel("Count")
plt.ylabel("Genre")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='duration', y='genre', data=df)
plt.title("Distribution of Movie Duration by Genre")
plt.xlabel("Duration (minutes)")
plt.ylabel("Genre")
plt.show()

# %%
from collections import Counter
import ast

# Convert the actors list (which is a string) back to a Python list
df['actors_list'] = df['actors_list'].apply(ast.literal_eval)

# Flatten and count all actors
actor_counts = Counter([actor for actors in df['actors_list'] for actor in actors])
top_10_actors = actor_counts.most_common(10)

# Create a DataFrame for visualization
top_actors_df = pd.DataFrame(top_10_actors, columns=['Actor', 'Count'])

plt.figure(figsize=(10, 6))
sns.barplot(x='Count', y='Actor', data=top_actors_df, palette='viridis')
plt.title("Top 10 Most Frequent Actors")
plt.xlabel("Number of Appearances")
plt.ylabel("Actor")
plt.show()
# Out:
# /tmp/ipython-input-3393482057.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Count', y='Actor', data=top_actors_df, palette='viridis')

# %%
# Convert actors_list back to list if it's a string
df['actors_list'] = df['actors_list'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# Create subplot grid (2 rows, 2 columns)
fig, axes = plt.subplots(2, 2, figsize=(15, 10))

# ---------------- Plot 1: Distribution of Ratings ----------------
sns.histplot(df['rating'], bins=10, kde=True, ax=axes[0, 0], color='skyblue')
axes[0, 0].set_title("Distribution of Movie Ratings")
axes[0, 0].set_xlabel("Rating")
axes[0, 0].set_ylabel("Frequency")

# ---------------- Plot 2: Count of Movies by Genre ----------------
sns.countplot(y='genre', data=df, order=df['genre'].value_counts().index, ax=axes[0, 1], palette='viridis')
axes[0, 1].set_title("Number of Movies by Genre")
axes[0, 1].set_xlabel("Count")
axes[0, 1].set_ylabel("Genre")

# ---------------- Plot 3: Duration by Genre ----------------
sns.boxplot(x='duration', y='genre', data=df, ax=axes[1, 0], palette='coolwarm')
axes[1, 0].set_title("Movie Duration by Genre")
axes[1, 0].set_xlabel("Duration (minutes)")
axes[1, 0].set_ylabel("Genre")

# ---------------- Plot 4: Top 10 Actors ----------------
actor_counts = Counter([actor for actors in df['actors_list'] for actor in actors])
top_10_actors = actor_counts.most_common(10)
top_actors_df = pd.DataFrame(top_10_actors, columns=['Actor', 'Count'])
sns.barplot(x='Count', y='Actor', data=top_actors_df, ax=axes[1, 1], palette='magma')
axes[1, 1].set_title("Top 10 Most Frequent Actors")
axes[1, 1].set_xlabel("Appearances")
axes[1, 1].set_ylabel("Actor")

# Adjust spacing
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-1927319916.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y='genre', data=df, order=df['genre'].value_counts().index, ax=axes[0, 1], palette='viridis')
# /tmp/ipython-input-1927319916.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='duration', y='genre', data=df, ax=axes[1, 0], palette='coolwarm')
# /tmp/ipython-input-1927319916.py:29: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Count', y='Actor', data=top_actors_df, ax=axes[1, 1], palette='magma')
